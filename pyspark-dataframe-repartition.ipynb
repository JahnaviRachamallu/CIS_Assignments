# %%
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('SparkByExamples.com') \
        .master("local[5]").getOrCreate()

df=spark.range(0,20)
df.collect()
print(df.rdd.getNumPartitions())
df2 = df.repartition(6)
print(df2.rdd.getNumPartitions())

df3 = df.coalesce(2)
print(df3.rdd.getNumPartitions())

df4 = df.groupBy("id").count()
print(df4.rdd.getNumPartitions())
# Out:
# 8
# 6
# 2
# 8

# %%
# Out:
# ['Hello', 'world', 'Sparkisawesome', 'FlatMap', 'example']

# %%
from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder.appName("GroupByExample").getOrCreate()

# Create a DataFrame with sample data
data = [
    ("Alice", "Math", 90),
    ("Bob", "Math", 80),
    ("Alice", "Science", 95),
    ("Bob", "Science", 85),
    ("Alice", "English", 75),
    ("Bob", "English", 70)
]
columns = ["Name", "Subject", "Score"]
df = spark.createDataFrame(data, columns)

# Group the DataFrame by "Name" column
grouped_df = df.groupBy("Name")

# Perform an aggregation on the grouped data
average_scores_df = grouped_df.avg("Score")
average_scores_df.collect()
# Out:
# Out[5]: [Row(Name='Alice', avg(Score)=86.66666666666667),
#  Row(Name='Bob', avg(Score)=78.33333333333333)]

# %%
# Out:
# <pyspark.sql.session.SparkSession object at 0x7f526db8acd0>
